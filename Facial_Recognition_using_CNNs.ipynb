# %% [markdown]
# # Deep Learning Assignment 4: CNNs for Face Identification
#
# We will perform face identification using a subset of the [Labeled Faces in the Wild (LFW) dataset](http://vis-www.cs.umass.edu/lfw/). Face identification is a multi-class calssification problem where we have training/testing images for a set of subjects (classes). In 2014, researchers were able to surpass human accuracy in facial identification tasks using CNN models (along with advanced deep learning techniques)!
#
# We will observe the performance of a traditional face identification method, [Eigenfaces](https://en.wikipedia.org/wiki/Eigenface). We will then build a CNN model in order to surpass the accuracy of the traditional Eigenfaces technique. In the process, we will learn about the great power of CNNs!
#
# ### Requirements
#
# 1. Python 3.6
# 2. `pip install numpy`
# 3. `pip install sklearn`
# 4. `pip install matplotlib`
# 5. `pip install tensorflow==2.0.0`

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Activation, Conv2D, MaxPool2D, AveragePooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
import matplotlib.pyplot as plt

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# Let's start by downloading and setting up a subset of the aligned and segmented version of the LFW dataset. We will only get subjects with at least 20 corresponding images. We will also get the grayscale versions of the images. This may take a few minutes . . .

# %%
data_x, data_y = fetch_lfw_people(min_faces_per_person=20, color=False, return_X_y=True)
# normalize pixel values to [0,1]
data_x = data_x / 255.

# %% [markdown]
# The downloaded `data_x` will be the flattened vector representation of the images.
#
# We will reshape the vector respresentations back into the original grayscale images and store the images back in `data_x`.

# %%
num_subjects = np.unique(data_y).shape[0]
print("Number of subjects: {}".format(np.unique(data_y).shape[0]))
print("Number of images: {}\n".format(data_y.shape[0]))

# image_x will contain the original grayscale images 
data_x = np.copy(data_x.reshape((data_x.shape[0], 62, 47, 1)))

print("data_x shape: {}".format(data_x.shape))
print("data_y shape: {}".format(data_y.shape))
# Out:
# Number of subjects: 62
# Number of images: 3023
#
# data_x shape: (3023, 62, 47, 1)
# data_y shape: (3023,)

# %% [markdown]
# As we can see, the dataset is made up of `3023` images of `62` subjects (or classes).
#
# Each image is a `62x47x1`-dimensional matrix containing 8-bit (0-255) grayscale pixel values.
#
# Let's visualize a few of the grayscale images.

# %%
np.random.seed(42)
for i in range(5):
    rnd_idx = np.random.choice(data_y.shape[0])
    rnd_img = data_x[rnd_idx]
    plt.figure()
    plt.imshow(rnd_img[:, :, 0], cmap="gray")

# %% [markdown]
# Now, let's split the dataset into train and test sets so we can perform face identification!
#
# We will perform a `90/10` stratified split. This means that `90%` of each subject's images are placed in the train set, while the remaining `10%` of each subject's images are placed into the test set.

# %%
train_x, test_x, train_y, test_y = train_test_split(data_x, data_y, test_size=0.1, random_state=42)

print("train_x shape: {}".format(train_x.shape))
print("train_y shape: {}\n".format(train_y.shape))

print("test_x shape: {}".format(test_x.shape))
print("test_y shape: {}".format(test_y.shape))
# Out:
# train_x shape: (2720, 62, 47, 1)
# train_y shape: (2720,)
#
# test_x shape: (303, 62, 47, 1)
# test_y shape: (303,)

# %% [markdown]
# ### Eigenfaces Overview
#
# Eigenfaces is a face identification technique proposed in 1987. It was a very popular algorithm through the 1990's and is still used today as a baseline algorithm when gauging the performance of proposed face identification techniques. Eigenfaces is used to extract features from facial images. Such facial features are more useful in identification tasks than the corresponding oringinal images. The facial features can then be used for identification by being classified by a multi-class classifier, such a logistic regression model.
#
# ### Eigenfaces Details
#
# Eigenfaces is a Principcal Componet Analysis (PCA)-based dimensionality-reduction technique. Eigenfaces deals with the flattened vector representations of the face images.
#
# We give the vector representation of the training images as input to the algorithm. The output of the algoirthm is a set of Eigenfaces (vectors) which we can use to project vector representations of images into a lower-dimensional space which (hopefully) encode important facial features.
#
# Since the lower-dimensional space captures important facial features, Eigenfaces is used as a feature extraction technique. Given a facial image, we can reshape the image into a vector. Using the Eigenfaces, we reduce the dimensionality of the original vector into a vector which is more useful in identifying its corresponging subject. Therefore, we will use the Eigenfaces to extract facial features. Then, we will use a simple logistic regression classifier to classify the resulting facial features.
#
# Let's start by flattening the training facial images. Then we will continue by computing the Eigenfaces which capture `95%` of the variance of the original dataset.

# %%
# flatten images 
train_vector_x = train_x.reshape((train_x.shape[0], train_x.shape[1]*train_x.shape[2])) 
test_vector_x = test_x.reshape((test_x.shape[0], test_x.shape[1]*test_x.shape[2])) 

# retrieve eigenfaces
pca = PCA(n_components=0.95, random_state=42)
pca.fit(train_vector_x)
eigenfaces = pca.components_

print("Training vectors shape: {}".format(train_vector_x.shape))
print("Eigenfaces shape: {}".format(eigenfaces.shape))
# Out:
# Training vectors shape: (2720, 2914)
# Eigenfaces shape: (173, 2914)

# %% [markdown]
# As we see, if we flatten the training images to gather their vector representations, we recieve `2720` vectors of size `2914`. We also see that we have found `173` Eigenfaces vectors of size `2914`.
#
# If we reshape the set of Eigenfaces to the shape of the original images, they reveal intesting ghost faces (i.e. "Eigenfaces").
#
# Let's view the first `10` Eigenfaces.

# %%
for i in range(10):
    eigenface = eigenfaces[i].reshape((train_x.shape[1], train_x.shape[2]))
    plt.figure()
    plt.imshow(eigenface, cmap="gray")

# %% [markdown]
# Spooky!
#
# Now, let's use the Eigenfaces to extract facial features from the training and test set vectors. Since we have `173` Eigenfaces, we will reduce the dimensionality of the `2914`-dimensional train/test vectors to `173`-dimensional train/test feature vectors.

# %%
train_features_x = np.dot(train_vector_x, eigenfaces.T)
test_features_x = np.dot(test_vector_x, eigenfaces.T)

print("Training vectors shape: {}".format(train_vector_x.shape))
print("Training features shape: {}".format(train_features_x.shape))
print("Testing vectors shape: {}".format(test_vector_x.shape))
print("Testing features shape: {}".format(test_features_x.shape))
# Out:
# Training vectors shape: (2720, 2914)
# Training features shape: (2720, 173)
# Testing vectors shape: (303, 2914)
# Testing features shape: (303, 173)

# %% [markdown]
# Great! Now that we have extracted facial features from the train and testing set, let's perform facial identification using a simple logistic regression model!

# %%
# specify the input size of the feature vectors
features = Input((train_features_x.shape[1],))
# a single fully-connected layer to map the features to a logit vector with one logit per subject
x = Dense(num_subjects)(features)
# use softmax activation to convert the logits to class probabilities for each subject
predictions = Activation("softmax")(x)

# create the model using the layers we defined previously
logistic_regression = Model(inputs=features, outputs=predictions)

# compile the model so that it uses Adam for optimization during training with cross-entropy loss
logistic_regression.compile(optimizer=Adam(), loss="sparse_categorical_crossentropy", metrics=["acc"])

# print out a summary of the model achitecture
print(logistic_regression.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 173)]             0
#
#  dense (Dense)               (None, 62)                10788
#
#  activation (Activation)     (None, 62)                0
#
# =================================================================
# Total params: 10,788
# Trainable params: 10,788
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# since the subjects have different numbers of images, 
# we need to balance how much each subject contributes to the cross-entropy loss
# class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(train_y), y=train_y)
class_weights = dict(enumerate(compute_class_weight(class_weight = 'balanced', classes = np.unique(train_y), y= train_y)))

# train model, verbose set to 0 to supress output, wait a moment for training to complete
logistic_regression.fit(train_features_x, train_y, validation_data=(test_features_x, test_y), 
                        class_weight=class_weights, 
                        epochs=75, batch_size=128, verbose=0)

# evaluate model, get train/test accuracy
train_eig_pred = np.argmax(logistic_regression.predict(train_features_x), axis=1)
test_eig_pred = np.argmax(logistic_regression.predict(test_features_x), axis=1)
print("\nTraining accuracy using Eigenfaces and logistic regression model: {}".format(accuracy_score(train_y, train_eig_pred)))
print("Testing accuracy using Eigenfaces and logistic regression model: {}".format(accuracy_score(test_y, test_eig_pred)))
# Out:
# 85/85 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 880us/step
#
# Training accuracy using Eigenfaces and logistic regression model: 0.8783088235294118
# Testing accuracy using Eigenfaces and logistic regression model: 0.6006600660066007

# %% [markdown]
# ### Sample CNN Model
# The Eigenfaces and logistic regression model doesn't perform that well on the unseen test set. Let's see how a simple CNN model compares.
#
# Rather than dealing with vectors, we will begin working with the grayscale images directly.
#
# Remember that a CNN learns convolution filters which extract the most useful features. Then, a small neural network at the end of the CNN architecture performs the multi-class classification. Therefore, the CNN will make things less complex for us as the CNN will learn to perform both feature extraction and classification!
#
# <b> Complete the section below</b>

# %%
# COMPLETE THE CODE ACCORDING TO THE COMMENTS

from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from keras.models import Model
from keras.optimizers import Adam

# specify the input size of the images
images = Input((train_x.shape[1], train_x.shape[2], 1,))
# a convolution layer of 32 filters of size 9x9 to extract features (valid padding)
x = Conv2D(32, (9, 9), padding='valid', activation='relu')(images)
# a maxpooling layer to down-sample features with pool size (2, 2)
x = MaxPooling2D(pool_size=(2, 2))(x)
# another convolution layer of 64 filters of size 11x11 to extract features (valid padding)
x = Conv2D(64, (11, 11), padding='valid', activation='relu')(x)
# a maxpooling layer to down-sample features with pool size (2, 2)
x = MaxPooling2D(pool_size=(2, 2))(x)
# flatten extracted features to form feature vector
x = Flatten()(x)
# a drop out layer for regularization (25% probability)
x = Dropout(0.25)(x)
# first fully-connected layer to map the features to vectors of size 256
x = Dense(256, activation='relu')(x)
# anoter drop out layer for regularization (25% probability)
x = Dropout(0.25)(x)
# a second fully-connected layer to map the features to a logit vector with one logit per subject
x = Dense(len(np.unique(train_y)), activation=None)(x)
# use softmax activation to convert the logits to class probabilities for each subject
predictions = Dense(len(np.unique(train_y)), activation='softmax')(x)

# create the model using the layers we defined previously
sample_cnn = Model(inputs=images, outputs=predictions)

# compile the model so that it uses Adam for optimization during training with cross-entropy loss
sample_cnn.compile(optimizer=Adam(), loss="sparse_categorical_crossentropy", metrics=["acc"])

# print out a summary of the model achitecture
print(sample_cnn.summary())
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 62, 47, 1)]       0
#
#  conv2d (Conv2D)             (None, 54, 39, 32)        2624
#
#  max_pooling2d (MaxPooling2D  (None, 27, 19, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 17, 9, 64)         247872
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 256)               524544
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 62)                15934
#
#  dense_3 (Dense)             (None, 62)                3906
#
# =================================================================
# Total params: 794,880
# Trainable params: 794,880
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# since the subjects have different numbers of images, 
# we need to balance how much each subject contributes to the cross-entropy loss
class_weights =  dict(enumerate(compute_class_weight(class_weight = 'balanced', classes = np.unique(train_y), y= train_y)))

# train model
sample_cnn.fit(train_x, train_y, validation_data=(test_x, test_y), 
                class_weight=class_weights,
               epochs=30, batch_size=64, verbose=1)

# evaluate model, get train/test accuracy
train_pred = np.argmax(sample_cnn.predict(train_x), axis=1)
test_pred = np.argmax(sample_cnn.predict(test_x), axis=1)
print("\nTraining accuracy using sample CNN model: {}".format(accuracy_score(train_y, train_pred)))
print("Testing accuracy using sample CNN model: {}\n".format(accuracy_score(test_y, test_pred)))

print("The sample CNN model beat the Eigenfaces and logistic regression model! :)")
print("Training accuracy using Eigenfaces and logistic regression model: {}".format(accuracy_score(train_y, train_eig_pred)))
print("Testing accuracy using Eigenfaces and logistic regression model: {}".format(accuracy_score(test_y, test_eig_pred)))
# Out:
# Epoch 1/30
# 43/43 [==============================] - 7s 161ms/step - loss: 0.4130 - acc: 0.8062 - val_loss: 1.9983 - val_acc: 0.5875
# Epoch 2/30
# 43/43 [==============================] - 7s 164ms/step - loss: 0.4059 - acc: 0.8070 - val_loss: 2.0393 - val_acc: 0.5644
# Epoch 3/30
# 43/43 [==============================] - 7s 164ms/step - loss: 0.3496 - acc: 0.8213 - val_loss: 2.0745 - val_acc: 0.5710
# Epoch 4/30
# 43/43 [==============================] - 7s 164ms/step - loss: 0.3947 - acc: 0.8074 - val_loss: 2.0105 - val_acc: 0.5809
# Epoch 5/30
# 43/43 [==============================] - 7s 165ms/step - loss: 0.3080 - acc: 0.8364 - val_loss: 1.9703 - val_acc: 0.6040
# Epoch 6/30
# 43/43 [==============================] - 8s 179ms/step - loss: 0.2953 - acc: 0.8507 - val_loss: 1.9359 - val_acc: 0.6040
# Epoch 7/30
# 43/43 [==============================] - 8s 185ms/step - loss: 0.3332 - acc: 0.8250 - val_loss: 1.9693 - val_acc: 0.6172
# Epoch 8/30
# 43/43 [==============================] - 8s 181ms/step - loss: 0.3171 - acc: 0.8254 - val_loss: 2.0179 - val_acc: 0.5974
# Epoch 9/30
# 43/43 [==============================] - 8s 183ms/step - loss: 0.2931 - acc: 0.8316 - val_loss: 1.9697 - val_acc: 0.6172
# Epoch 10/30
# 43/43 [==============================] - 8s 180ms/step - loss: 0.2983 - acc: 0.8441 - val_loss: 2.0494 - val_acc: 0.5875
# Epoch 11/30
# 43/43 [==============================] - 8s 183ms/step - loss: 0.3048 - acc: 0.8375 - val_loss: 2.1110 - val_acc: 0.6106
# Epoch 12/30
# 43/43 [==============================] - 8s 186ms/step - loss: 0.2670 - acc: 0.8559 - val_loss: 1.9874 - val_acc: 0.6271
# Epoch 13/30
# 43/43 [==============================] - 8s 191ms/step - loss: 0.2712 - acc: 0.8382 - val_loss: 2.1436 - val_acc: 0.5941
# Epoch 14/30
# 43/43 [==============================] - 8s 183ms/step - loss: 0.2884 - acc: 0.8434 - val_loss: 2.0152 - val_acc: 0.6139
# Epoch 15/30
# 43/43 [==============================] - 8s 184ms/step - loss: 0.2937 - acc: 0.8313 - val_loss: 2.0779 - val_acc: 0.6073
# Epoch 16/30
# 43/43 [==============================] - 8s 197ms/step - loss: 0.2304 - acc: 0.8706 - val_loss: 2.0966 - val_acc: 0.6106
# Epoch 17/30
# 43/43 [==============================] - 8s 190ms/step - loss: 0.2487 - acc: 0.8610 - val_loss: 1.9582 - val_acc: 0.6205
# Epoch 18/30
# 43/43 [==============================] - 8s 190ms/step - loss: 0.2920 - acc: 0.8533 - val_loss: 2.0745 - val_acc: 0.6139
# Epoch 19/30
# 43/43 [==============================] - 8s 187ms/step - loss: 0.2429 - acc: 0.8496 - val_loss: 2.0684 - val_acc: 0.6106
# Epoch 20/30
# 43/43 [==============================] - 8s 192ms/step - loss: 0.2632 - acc: 0.8415 - val_loss: 2.1116 - val_acc: 0.5908
# Epoch 21/30
# 43/43 [==============================] - 9s 200ms/step - loss: 0.2899 - acc: 0.8452 - val_loss: 1.9495 - val_acc: 0.6238
# Epoch 22/30
# 43/43 [==============================] - 8s 192ms/step - loss: 0.2751 - acc: 0.8548 - val_loss: 2.0374 - val_acc: 0.6007
# Epoch 23/30
# 43/43 [==============================] - 8s 196ms/step - loss: 0.2758 - acc: 0.8445 - val_loss: 1.9805 - val_acc: 0.6205
# Epoch 24/30
# 43/43 [==============================] - 8s 190ms/step - loss: 0.2299 - acc: 0.8717 - val_loss: 2.0294 - val_acc: 0.6271
# Epoch 25/30
# 43/43 [==============================] - 8s 191ms/step - loss: 0.2560 - acc: 0.8522 - val_loss: 2.0586 - val_acc: 0.6403
# Epoch 26/30
# 43/43 [==============================] - 9s 204ms/step - loss: 0.2103 - acc: 0.8724 - val_loss: 2.1265 - val_acc: 0.6106
# Epoch 27/30
# 43/43 [==============================] - 9s 199ms/step - loss: 0.2055 - acc: 0.8654 - val_loss: 2.0910 - val_acc: 0.6238
# Epoch 28/30
# 43/43 [==============================] - 9s 214ms/step - loss: 0.2342 - acc: 0.8673 - val_loss: 2.1484 - val_acc: 0.6139
# Epoch 29/30
# 43/43 [==============================] - 8s 198ms/step - loss: 0.2562 - acc: 0.8643 - val_loss: 2.2317 - val_acc: 0.5908
# Epoch 30/30
# 43/43 [==============================] - 9s 199ms/step - loss: 0.2712 - acc: 0.8548 - val_loss: 2.2692 - val_acc: 0.6337
# 85/85 [==============================] - 2s 25ms/step
# 10/10 [==============================] - 0s 25ms/step
#
# Training accuracy using sample CNN model: 0.9540441176470589
# Testing accuracy using sample CNN model: 0.6336633663366337
#
# The sample CNN model beat the Eigenfaces and logistic regression model! :)
# Training accuracy using Eigenfaces and logistic regression model: 0.8783088235294118
# Testing accuracy using Eigenfaces and logistic regression model: 0.6006600660066007

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from keras.models import Model
from keras.optimizers import Adam
from keras.models import Sequential

# define the model architecture
subjects = np.unique(train_y)
model1 = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(train_x.shape[1],train_x.shape[2],1)),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(subjects), activation='softmax')
])

# compile the model
model1.compile(optimizer=RMSprop(), loss='sparse_categorical_crossentropy', metrics=['acc'])
history1 = model1.fit(train_x, train_y, epochs=75, batch_size=32, validation_data=(test_x, test_y))
test_loss1, test_acc1 = model1.evaluate(test_x, test_y)
# Out:
# Epoch 1/75
# 85/85 [==============================] - 4s 39ms/step - loss: 3.7474 - acc: 0.1713 - val_loss: 3.6563 - val_acc: 0.1584
# Epoch 2/75
# 85/85 [==============================] - 3s 36ms/step - loss: 3.5581 - acc: 0.1860 - val_loss: 3.5272 - val_acc: 0.2079
# Epoch 3/75
# 85/85 [==============================] - 3s 37ms/step - loss: 3.3805 - acc: 0.2070 - val_loss: 3.4155 - val_acc: 0.2409
# Epoch 4/75
# 85/85 [==============================] - 3s 38ms/step - loss: 3.1804 - acc: 0.2401 - val_loss: 3.3128 - val_acc: 0.1881
# Epoch 5/75
# 85/85 [==============================] - 3s 37ms/step - loss: 2.9563 - acc: 0.2739 - val_loss: 2.9761 - val_acc: 0.2805
# Epoch 6/75
# 85/85 [==============================] - 3s 37ms/step - loss: 2.6969 - acc: 0.3423 - val_loss: 2.7514 - val_acc: 0.3531
# Epoch 7/75
# 85/85 [==============================] - 3s 37ms/step - loss: 2.4240 - acc: 0.4033 - val_loss: 2.6369 - val_acc: 0.3861
# Epoch 8/75
# 85/85 [==============================] - 3s 37ms/step - loss: 2.1830 - acc: 0.4493 - val_loss: 2.5146 - val_acc: 0.3894
# Epoch 9/75
# 85/85 [==============================] - 4s 47ms/step - loss: 1.9798 - acc: 0.4908 - val_loss: 2.3189 - val_acc: 0.4422
# Epoch 10/75
# 85/85 [==============================] - 3s 37ms/step - loss: 1.8154 - acc: 0.5390 - val_loss: 2.1958 - val_acc: 0.4587
# Epoch 11/75
# 85/85 [==============================] - 3s 40ms/step - loss: 1.6562 - acc: 0.5787 - val_loss: 2.1477 - val_acc: 0.4983
# Epoch 12/75
# 85/85 [==============================] - 4s 41ms/step - loss: 1.5209 - acc: 0.6000 - val_loss: 2.0997 - val_acc: 0.5149
# Epoch 13/75
# 85/85 [==============================] - 3s 41ms/step - loss: 1.4084 - acc: 0.6390 - val_loss: 2.0215 - val_acc: 0.5215
# Epoch 14/75
# 85/85 [==============================] - 3s 40ms/step - loss: 1.3042 - acc: 0.6562 - val_loss: 1.9895 - val_acc: 0.5380
# Epoch 15/75
# 85/85 [==============================] - 3s 39ms/step - loss: 1.1975 - acc: 0.6853 - val_loss: 2.0883 - val_acc: 0.5149
# Epoch 16/75
# 85/85 [==============================] - 3s 40ms/step - loss: 1.1131 - acc: 0.7077 - val_loss: 2.0200 - val_acc: 0.5182
# Epoch 17/75
# 85/85 [==============================] - 3s 38ms/step - loss: 1.0073 - acc: 0.7386 - val_loss: 1.9675 - val_acc: 0.5644
# Epoch 18/75
# 85/85 [==============================] - 4s 42ms/step - loss: 0.9293 - acc: 0.7456 - val_loss: 1.9142 - val_acc: 0.5677
# Epoch 19/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.8367 - acc: 0.7798 - val_loss: 1.9256 - val_acc: 0.5842
# Epoch 20/75
# 85/85 [==============================] - 3s 41ms/step - loss: 0.7702 - acc: 0.8029 - val_loss: 2.0589 - val_acc: 0.5710
# Epoch 21/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.6876 - acc: 0.8228 - val_loss: 1.8998 - val_acc: 0.5743
# Epoch 22/75
# 85/85 [==============================] - 4s 42ms/step - loss: 0.6277 - acc: 0.8338 - val_loss: 1.9645 - val_acc: 0.6106
# Epoch 23/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.5724 - acc: 0.8511 - val_loss: 1.8931 - val_acc: 0.6106
# Epoch 24/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.5091 - acc: 0.8721 - val_loss: 2.0367 - val_acc: 0.5941
# Epoch 25/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.4558 - acc: 0.8842 - val_loss: 2.0122 - val_acc: 0.6073
# Epoch 26/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.4019 - acc: 0.9000 - val_loss: 2.0083 - val_acc: 0.6073
# Epoch 27/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.3465 - acc: 0.9121 - val_loss: 1.9722 - val_acc: 0.6304
# Epoch 28/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.3043 - acc: 0.9301 - val_loss: 1.9544 - val_acc: 0.6370
# Epoch 29/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.2665 - acc: 0.9460 - val_loss: 1.9936 - val_acc: 0.6139
# Epoch 30/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.2219 - acc: 0.9537 - val_loss: 2.1731 - val_acc: 0.6403
# Epoch 31/75
# 85/85 [==============================] - 3s 41ms/step - loss: 0.1915 - acc: 0.9618 - val_loss: 2.1987 - val_acc: 0.6337
# Epoch 32/75
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1679 - acc: 0.9680 - val_loss: 2.2539 - val_acc: 0.6370
# Epoch 33/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.1473 - acc: 0.9750 - val_loss: 2.4424 - val_acc: 0.6337
# Epoch 34/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.1159 - acc: 0.9809 - val_loss: 2.3227 - val_acc: 0.6370
# Epoch 35/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.1019 - acc: 0.9868 - val_loss: 2.3916 - val_acc: 0.6370
# Epoch 36/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0800 - acc: 0.9890 - val_loss: 2.3445 - val_acc: 0.6172
# Epoch 37/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.0677 - acc: 0.9912 - val_loss: 2.5146 - val_acc: 0.6337
# Epoch 38/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0602 - acc: 0.9949 - val_loss: 2.6732 - val_acc: 0.6238
# Epoch 39/75
# 85/85 [==============================] - 3s 41ms/step - loss: 0.0432 - acc: 0.9967 - val_loss: 2.5210 - val_acc: 0.6073
# Epoch 40/75
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0348 - acc: 0.9974 - val_loss: 2.5461 - val_acc: 0.6238
# Epoch 41/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0282 - acc: 0.9985 - val_loss: 2.7230 - val_acc: 0.6304
# Epoch 42/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0316 - acc: 0.9960 - val_loss: 2.7007 - val_acc: 0.6469
# Epoch 43/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.0186 - acc: 0.9989 - val_loss: 2.8145 - val_acc: 0.6436
# Epoch 44/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0148 - acc: 0.9993 - val_loss: 2.9004 - val_acc: 0.6469
# Epoch 45/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0115 - acc: 1.0000 - val_loss: 3.0014 - val_acc: 0.6205
# Epoch 46/75
# 85/85 [==============================] - 3s 39ms/step - loss: 0.0112 - acc: 0.9989 - val_loss: 3.1259 - val_acc: 0.6304
# Epoch 47/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 3.1168 - val_acc: 0.6337
# Epoch 48/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0039 - acc: 1.0000 - val_loss: 3.2225 - val_acc: 0.6469
# Epoch 49/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 3.2428 - val_acc: 0.6436
# Epoch 50/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 3.4910 - val_acc: 0.6370
# Epoch 51/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 3.5060 - val_acc: 0.6304
# Epoch 52/75
# 85/85 [==============================] - 3s 40ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 3.6049 - val_acc: 0.6469
# Epoch 53/75
# 85/85 [==============================] - 3s 40ms/step - loss: 9.5192e-04 - acc: 1.0000 - val_loss: 3.6703 - val_acc: 0.6403
# Epoch 54/75
# 85/85 [==============================] - 3s 39ms/step - loss: 7.7921e-04 - acc: 1.0000 - val_loss: 3.7660 - val_acc: 0.6370
# Epoch 55/75
# 85/85 [==============================] - 3s 40ms/step - loss: 6.3419e-04 - acc: 1.0000 - val_loss: 3.8631 - val_acc: 0.6271
# Epoch 56/75
# 85/85 [==============================] - 3s 40ms/step - loss: 5.0833e-04 - acc: 1.0000 - val_loss: 3.9786 - val_acc: 0.6205
# Epoch 57/75
# 85/85 [==============================] - 3s 40ms/step - loss: 4.1026e-04 - acc: 1.0000 - val_loss: 4.0477 - val_acc: 0.6304
# Epoch 58/75
# 85/85 [==============================] - 3s 40ms/step - loss: 3.3362e-04 - acc: 1.0000 - val_loss: 4.1783 - val_acc: 0.6172
# Epoch 59/75
# 85/85 [==============================] - 4s 41ms/step - loss: 2.7317e-04 - acc: 1.0000 - val_loss: 4.2137 - val_acc: 0.6238
# Epoch 60/75
# 85/85 [==============================] - 3s 39ms/step - loss: 2.3956e-04 - acc: 1.0000 - val_loss: 4.2910 - val_acc: 0.6403
# Epoch 61/75
# 85/85 [==============================] - 3s 39ms/step - loss: 1.9736e-04 - acc: 1.0000 - val_loss: 4.3139 - val_acc: 0.6403
# Epoch 62/75
# 85/85 [==============================] - 3s 40ms/step - loss: 1.7776e-04 - acc: 1.0000 - val_loss: 4.4229 - val_acc: 0.6304
# Epoch 63/75
# 85/85 [==============================] - 3s 40ms/step - loss: 1.5412e-04 - acc: 1.0000 - val_loss: 4.4724 - val_acc: 0.6304
# Epoch 64/75
# 85/85 [==============================] - 3s 40ms/step - loss: 1.3174e-04 - acc: 1.0000 - val_loss: 4.5292 - val_acc: 0.6271
# Epoch 65/75
# 85/85 [==============================] - 3s 40ms/step - loss: 1.1636e-04 - acc: 1.0000 - val_loss: 4.5155 - val_acc: 0.6205
# Epoch 66/75
# 85/85 [==============================] - 3s 39ms/step - loss: 1.1200e-04 - acc: 1.0000 - val_loss: 4.5706 - val_acc: 0.6271
# Epoch 67/75
# 85/85 [==============================] - 3s 40ms/step - loss: 9.8762e-05 - acc: 1.0000 - val_loss: 4.5641 - val_acc: 0.6337
# Epoch 68/75
# 85/85 [==============================] - 3s 40ms/step - loss: 8.9365e-05 - acc: 1.0000 - val_loss: 4.7075 - val_acc: 0.6304
# Epoch 69/75
# 85/85 [==============================] - 3s 40ms/step - loss: 8.0606e-05 - acc: 1.0000 - val_loss: 4.6977 - val_acc: 0.6337
# Epoch 70/75
# 85/85 [==============================] - 3s 40ms/step - loss: 7.8017e-05 - acc: 1.0000 - val_loss: 4.6891 - val_acc: 0.6337
# Epoch 71/75
# 85/85 [==============================] - 3s 41ms/step - loss: 7.1299e-05 - acc: 1.0000 - val_loss: 4.7303 - val_acc: 0.6337
# Epoch 72/75
# 85/85 [==============================] - 3s 40ms/step - loss: 6.6778e-05 - acc: 1.0000 - val_loss: 4.7368 - val_acc: 0.6304
# Epoch 73/75
# 85/85 [==============================] - 4s 41ms/step - loss: 6.1316e-05 - acc: 1.0000 - val_loss: 4.7969 - val_acc: 0.6304
# Epoch 74/75
# 85/85 [==============================] - 3s 40ms/step - loss: 5.9070e-05 - acc: 1.0000 - val_loss: 4.8091 - val_acc: 0.6403
# Epoch 75/75
# 85/85 [==============================] - 3s 41ms/step - loss: 5.4149e-05 - acc: 1.0000 - val_loss: 4.8307 - val_acc: 0.6337
# 10/10 [==============================] - 0s 12ms/step - loss: 4.8307 - acc: 0.6337

# %%
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

# define the model 2 architecture
model2 = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(train_x.shape[1],train_x.shape[2],1)),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(len(subjects), activation='softmax')
])


# compile the model
model2.compile(optimizer=RMSprop(), loss='sparse_categorical_crossentropy', metrics=['acc'])
history2 = model2.fit(train_x, train_y, epochs=75, batch_size=64, validation_data=(test_x, test_y))
test_loss2, test_acc2 = model2.evaluate(test_x, test_y)
# Out:
# Epoch 1/75
# 43/43 [==============================] - 6s 131ms/step - loss: 3.8953 - acc: 0.1562 - val_loss: 3.8735 - val_acc: 0.1485
# Epoch 2/75
# 43/43 [==============================] - 6s 147ms/step - loss: 3.7612 - acc: 0.1768 - val_loss: 3.7158 - val_acc: 0.1485
# Epoch 3/75
# 43/43 [==============================] - 6s 150ms/step - loss: 3.7332 - acc: 0.1765 - val_loss: 3.7891 - val_acc: 0.1485
# Epoch 4/75
# 43/43 [==============================] - 7s 151ms/step - loss: 3.7071 - acc: 0.1783 - val_loss: 3.6756 - val_acc: 0.1485
# Epoch 5/75
# 43/43 [==============================] - 6s 146ms/step - loss: 3.6636 - acc: 0.1783 - val_loss: 3.6666 - val_acc: 0.1485
# Epoch 6/75
# 43/43 [==============================] - 7s 172ms/step - loss: 3.5676 - acc: 0.1783 - val_loss: 3.4987 - val_acc: 0.1485
# Epoch 7/75
# 43/43 [==============================] - 8s 181ms/step - loss: 3.4592 - acc: 0.1868 - val_loss: 3.5474 - val_acc: 0.1518
# Epoch 8/75
# 43/43 [==============================] - 7s 170ms/step - loss: 3.3574 - acc: 0.1923 - val_loss: 3.3645 - val_acc: 0.2376
# Epoch 9/75
# 43/43 [==============================] - 7s 161ms/step - loss: 3.2338 - acc: 0.2202 - val_loss: 3.0363 - val_acc: 0.2739
# Epoch 10/75
# 43/43 [==============================] - 7s 165ms/step - loss: 3.0434 - acc: 0.2592 - val_loss: 2.8385 - val_acc: 0.3399
# Epoch 11/75
# 43/43 [==============================] - 7s 162ms/step - loss: 2.8549 - acc: 0.3015 - val_loss: 2.7053 - val_acc: 0.3894
# Epoch 12/75
# 43/43 [==============================] - 7s 161ms/step - loss: 2.6542 - acc: 0.3382 - val_loss: 2.5264 - val_acc: 0.4125
# Epoch 13/75
# 43/43 [==============================] - 7s 172ms/step - loss: 2.4700 - acc: 0.3699 - val_loss: 2.5508 - val_acc: 0.4059
# Epoch 14/75
# 43/43 [==============================] - 8s 185ms/step - loss: 2.3180 - acc: 0.3974 - val_loss: 2.2453 - val_acc: 0.4323
# Epoch 15/75
# 43/43 [==============================] - 7s 166ms/step - loss: 2.1931 - acc: 0.4173 - val_loss: 2.5388 - val_acc: 0.3894
# Epoch 16/75
# 43/43 [==============================] - 8s 189ms/step - loss: 2.0519 - acc: 0.4515 - val_loss: 2.0460 - val_acc: 0.4554
# Epoch 17/75
# 43/43 [==============================] - 7s 159ms/step - loss: 1.9473 - acc: 0.4827 - val_loss: 2.0460 - val_acc: 0.5017
# Epoch 18/75
# 43/43 [==============================] - 7s 159ms/step - loss: 1.8166 - acc: 0.5110 - val_loss: 2.0136 - val_acc: 0.5017
# Epoch 19/75
# 43/43 [==============================] - 7s 159ms/step - loss: 1.6788 - acc: 0.5426 - val_loss: 1.6963 - val_acc: 0.5644
# Epoch 20/75
# 43/43 [==============================] - 7s 160ms/step - loss: 1.5854 - acc: 0.5540 - val_loss: 1.6771 - val_acc: 0.5842
# Epoch 21/75
# 43/43 [==============================] - 7s 157ms/step - loss: 1.4857 - acc: 0.5853 - val_loss: 1.7246 - val_acc: 0.5743
# Epoch 22/75
# 43/43 [==============================] - 7s 155ms/step - loss: 1.3966 - acc: 0.6110 - val_loss: 1.7709 - val_acc: 0.5347
# Epoch 23/75
# 43/43 [==============================] - 7s 157ms/step - loss: 1.2678 - acc: 0.6309 - val_loss: 1.6052 - val_acc: 0.5710
# Epoch 24/75
# 43/43 [==============================] - 7s 156ms/step - loss: 1.1851 - acc: 0.6618 - val_loss: 1.4654 - val_acc: 0.6271
# Epoch 25/75
# 43/43 [==============================] - 7s 156ms/step - loss: 1.0527 - acc: 0.6934 - val_loss: 1.4915 - val_acc: 0.6304
# Epoch 26/75
# 43/43 [==============================] - 7s 157ms/step - loss: 1.0198 - acc: 0.7040 - val_loss: 1.3690 - val_acc: 0.6403
# Epoch 27/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.8936 - acc: 0.7324 - val_loss: 1.6258 - val_acc: 0.6172
# Epoch 28/75
# 43/43 [==============================] - 7s 158ms/step - loss: 0.8701 - acc: 0.7342 - val_loss: 1.4048 - val_acc: 0.6502
# Epoch 29/75
# 43/43 [==============================] - 7s 155ms/step - loss: 0.7945 - acc: 0.7610 - val_loss: 1.3250 - val_acc: 0.6700
# Epoch 30/75
# 43/43 [==============================] - 7s 156ms/step - loss: 0.7201 - acc: 0.7794 - val_loss: 1.2947 - val_acc: 0.6898
# Epoch 31/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.6697 - acc: 0.7937 - val_loss: 1.3540 - val_acc: 0.6865
# Epoch 32/75
# 43/43 [==============================] - 7s 161ms/step - loss: 0.5787 - acc: 0.8224 - val_loss: 1.4369 - val_acc: 0.6832
# Epoch 33/75
# 43/43 [==============================] - 7s 156ms/step - loss: 0.5433 - acc: 0.8338 - val_loss: 1.4682 - val_acc: 0.6304
# Epoch 34/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.5246 - acc: 0.8434 - val_loss: 1.5154 - val_acc: 0.6568
# Epoch 35/75
# 43/43 [==============================] - 7s 155ms/step - loss: 0.4366 - acc: 0.8654 - val_loss: 1.4731 - val_acc: 0.7162
# Epoch 36/75
# 43/43 [==============================] - 7s 161ms/step - loss: 0.4380 - acc: 0.8651 - val_loss: 1.3214 - val_acc: 0.7063
# Epoch 37/75
# 43/43 [==============================] - 7s 174ms/step - loss: 0.3887 - acc: 0.8746 - val_loss: 1.3682 - val_acc: 0.6964
# Epoch 38/75
# 43/43 [==============================] - 7s 158ms/step - loss: 0.3461 - acc: 0.8875 - val_loss: 1.5459 - val_acc: 0.6799
# Epoch 39/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.3721 - acc: 0.8849 - val_loss: 1.3471 - val_acc: 0.7162
# Epoch 40/75
# 43/43 [==============================] - 7s 156ms/step - loss: 0.2978 - acc: 0.9096 - val_loss: 1.4186 - val_acc: 0.7063
# Epoch 41/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.3116 - acc: 0.9037 - val_loss: 1.3106 - val_acc: 0.7228
# Epoch 42/75
# 43/43 [==============================] - 7s 158ms/step - loss: 0.2840 - acc: 0.9107 - val_loss: 1.3566 - val_acc: 0.7261
# Epoch 43/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.2256 - acc: 0.9290 - val_loss: 1.5710 - val_acc: 0.6799
# Epoch 44/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.2349 - acc: 0.9224 - val_loss: 1.3572 - val_acc: 0.7096
# Epoch 45/75
# 43/43 [==============================] - 7s 159ms/step - loss: 0.2168 - acc: 0.9324 - val_loss: 1.4924 - val_acc: 0.7261
# Epoch 46/75
# 43/43 [==============================] - 7s 166ms/step - loss: 0.2075 - acc: 0.9294 - val_loss: 1.4293 - val_acc: 0.7195
# Epoch 47/75
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1704 - acc: 0.9456 - val_loss: 1.5434 - val_acc: 0.7459
# Epoch 48/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.2224 - acc: 0.9331 - val_loss: 1.6458 - val_acc: 0.6931
# Epoch 49/75
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1760 - acc: 0.9467 - val_loss: 1.6022 - val_acc: 0.7228
# Epoch 50/75
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1386 - acc: 0.9585 - val_loss: 1.7355 - val_acc: 0.7195
# Epoch 51/75
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1626 - acc: 0.9504 - val_loss: 1.5891 - val_acc: 0.7459
# Epoch 52/75
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1646 - acc: 0.9478 - val_loss: 1.4828 - val_acc: 0.7327
# Epoch 53/75
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1443 - acc: 0.9574 - val_loss: 1.5888 - val_acc: 0.7261
# Epoch 54/75
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1392 - acc: 0.9526 - val_loss: 1.6845 - val_acc: 0.7228
# Epoch 55/75
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1251 - acc: 0.9665 - val_loss: 1.6866 - val_acc: 0.7393
# Epoch 56/75
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1330 - acc: 0.9566 - val_loss: 1.6504 - val_acc: 0.7261
# Epoch 57/75
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1115 - acc: 0.9618 - val_loss: 1.8152 - val_acc: 0.7228
# Epoch 58/75
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1374 - acc: 0.9544 - val_loss: 1.6246 - val_acc: 0.7261
# Epoch 59/75
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1267 - acc: 0.9654 - val_loss: 1.7113 - val_acc: 0.6964
# Epoch 60/75
# 43/43 [==============================] - 9s 214ms/step - loss: 0.1222 - acc: 0.9614 - val_loss: 1.5049 - val_acc: 0.7558
# Epoch 61/75
# 43/43 [==============================] - 7s 171ms/step - loss: 0.1002 - acc: 0.9695 - val_loss: 1.8931 - val_acc: 0.6964
# Epoch 62/75
# 43/43 [==============================] - 7s 163ms/step - loss: 0.1195 - acc: 0.9651 - val_loss: 1.6838 - val_acc: 0.7195
# Epoch 63/75
# 43/43 [==============================] - 7s 165ms/step - loss: 0.1002 - acc: 0.9684 - val_loss: 1.6551 - val_acc: 0.7261
# Epoch 64/75
# 43/43 [==============================] - 7s 163ms/step - loss: 0.0889 - acc: 0.9688 - val_loss: 1.6054 - val_acc: 0.7558
# Epoch 65/75
# 43/43 [==============================] - 7s 164ms/step - loss: 0.0760 - acc: 0.9743 - val_loss: 1.9281 - val_acc: 0.7162
# Epoch 66/75
# 43/43 [==============================] - 7s 171ms/step - loss: 0.0920 - acc: 0.9702 - val_loss: 2.3444 - val_acc: 0.7063
# Epoch 67/75
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1153 - acc: 0.9673 - val_loss: 1.9642 - val_acc: 0.7096
# Epoch 68/75
# 43/43 [==============================] - 8s 175ms/step - loss: 0.0929 - acc: 0.9717 - val_loss: 1.7731 - val_acc: 0.7459
# Epoch 69/75
# 43/43 [==============================] - 7s 168ms/step - loss: 0.0693 - acc: 0.9750 - val_loss: 2.0772 - val_acc: 0.6700
# Epoch 70/75
# 43/43 [==============================] - 7s 165ms/step - loss: 0.0641 - acc: 0.9790 - val_loss: 1.8937 - val_acc: 0.7558
# Epoch 71/75
# 43/43 [==============================] - 7s 163ms/step - loss: 0.1051 - acc: 0.9684 - val_loss: 1.6855 - val_acc: 0.7591
# Epoch 72/75
# 43/43 [==============================] - 7s 169ms/step - loss: 0.0630 - acc: 0.9783 - val_loss: 1.5723 - val_acc: 0.7459
# Epoch 73/75
# 43/43 [==============================] - 7s 163ms/step - loss: 0.0930 - acc: 0.9739 - val_loss: 2.0403 - val_acc: 0.7360
# Epoch 74/75
# 43/43 [==============================] - 7s 163ms/step - loss: 0.0750 - acc: 0.9794 - val_loss: 1.9020 - val_acc: 0.7591
# Epoch 75/75
# 43/43 [==============================] - 7s 164ms/step - loss: 0.0793 - acc: 0.9754 - val_loss: 2.0924 - val_acc: 0.7063
# 10/10 [==============================] - 0s 24ms/step - loss: 2.0924 - acc: 0.7063

# %%
# define the model3 architecture
from keras.layers import BatchNormalization

model3 = Sequential([
    Conv2D(64, (3,3), activation='relu', input_shape=(train_x.shape[1],train_x.shape[2],1)),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Flatten(),
    Dropout(0.25),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(len(subjects), activation='softmax')
])

# compile the model
model3.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['acc'])
history3 = model3.fit(train_x, train_y, epochs=75, batch_size=128, validation_data=(test_x, test_y))
test_loss3, test_acc3 = model3.evaluate(test_x, test_y)
# Out:
# Epoch 1/75
# 22/22 [==============================] - 12s 504ms/step - loss: 4.5615 - acc: 0.1195 - val_loss: 3.8145 - val_acc: 0.1518
# Epoch 2/75
# 22/22 [==============================] - 11s 519ms/step - loss: 3.6897 - acc: 0.1871 - val_loss: 4.3601 - val_acc: 0.1485
# Epoch 3/75
# 22/22 [==============================] - 14s 624ms/step - loss: 3.5175 - acc: 0.2081 - val_loss: 4.4552 - val_acc: 0.1485
# Epoch 4/75
# 22/22 [==============================] - 15s 674ms/step - loss: 3.3037 - acc: 0.2375 - val_loss: 4.5544 - val_acc: 0.1485
# Epoch 5/75
# 22/22 [==============================] - 13s 589ms/step - loss: 3.1196 - acc: 0.2665 - val_loss: 5.2934 - val_acc: 0.0330
# Epoch 6/75
# 22/22 [==============================] - 13s 577ms/step - loss: 2.9585 - acc: 0.3048 - val_loss: 6.4826 - val_acc: 0.1518
# Epoch 7/75
# 22/22 [==============================] - 13s 581ms/step - loss: 2.7613 - acc: 0.3382 - val_loss: 7.0755 - val_acc: 0.1485
# Epoch 8/75
# 22/22 [==============================] - 13s 580ms/step - loss: 2.5814 - acc: 0.3809 - val_loss: 7.4129 - val_acc: 0.0462
# Epoch 9/75
# 22/22 [==============================] - 13s 577ms/step - loss: 2.3630 - acc: 0.4283 - val_loss: 7.5147 - val_acc: 0.0462
# Epoch 10/75
# 22/22 [==============================] - 13s 582ms/step - loss: 2.2147 - acc: 0.4452 - val_loss: 6.9032 - val_acc: 0.0792
# Epoch 11/75
# 22/22 [==============================] - 13s 601ms/step - loss: 2.1097 - acc: 0.4702 - val_loss: 7.6658 - val_acc: 0.0099
# Epoch 12/75
# 22/22 [==============================] - 13s 615ms/step - loss: 1.9199 - acc: 0.5129 - val_loss: 6.5720 - val_acc: 0.0330
# Epoch 13/75
# 22/22 [==============================] - 13s 587ms/step - loss: 1.7637 - acc: 0.5496 - val_loss: 6.5615 - val_acc: 0.0330
# Epoch 14/75
# 22/22 [==============================] - 13s 584ms/step - loss: 1.6371 - acc: 0.5761 - val_loss: 7.1846 - val_acc: 0.0099
# Epoch 15/75
# 22/22 [==============================] - 13s 580ms/step - loss: 1.5195 - acc: 0.5989 - val_loss: 8.5488 - val_acc: 0.0099
# Epoch 16/75
# 22/22 [==============================] - 13s 582ms/step - loss: 1.4555 - acc: 0.6180 - val_loss: 7.4357 - val_acc: 0.0759
# Epoch 17/75
# 22/22 [==============================] - 13s 588ms/step - loss: 1.2758 - acc: 0.6643 - val_loss: 6.8599 - val_acc: 0.1683
# Epoch 18/75
# 22/22 [==============================] - 13s 578ms/step - loss: 1.1985 - acc: 0.6739 - val_loss: 7.0205 - val_acc: 0.1815
# Epoch 19/75
# 22/22 [==============================] - 13s 584ms/step - loss: 1.1251 - acc: 0.6971 - val_loss: 5.5581 - val_acc: 0.2013
# Epoch 20/75
# 22/22 [==============================] - 14s 623ms/step - loss: 1.0632 - acc: 0.7004 - val_loss: 5.4165 - val_acc: 0.1881
# Epoch 21/75
# 22/22 [==============================] - 14s 643ms/step - loss: 0.9562 - acc: 0.7294 - val_loss: 5.8180 - val_acc: 0.1914
# Epoch 22/75
# 22/22 [==============================] - 13s 611ms/step - loss: 0.8891 - acc: 0.7551 - val_loss: 4.9879 - val_acc: 0.2145
# Epoch 23/75
# 22/22 [==============================] - 14s 645ms/step - loss: 0.8060 - acc: 0.7713 - val_loss: 3.1193 - val_acc: 0.3894
# Epoch 24/75
# 22/22 [==============================] - 13s 608ms/step - loss: 0.7728 - acc: 0.7820 - val_loss: 3.7293 - val_acc: 0.3531
# Epoch 25/75
# 22/22 [==============================] - 14s 615ms/step - loss: 0.7021 - acc: 0.7971 - val_loss: 2.2752 - val_acc: 0.4554
# Epoch 26/75
# 22/22 [==============================] - 14s 616ms/step - loss: 0.6504 - acc: 0.8096 - val_loss: 2.1142 - val_acc: 0.5479
# Epoch 27/75
# 22/22 [==============================] - 14s 638ms/step - loss: 0.6374 - acc: 0.8169 - val_loss: 2.3682 - val_acc: 0.5149
# Epoch 28/75
# 22/22 [==============================] - 13s 601ms/step - loss: 0.5384 - acc: 0.8393 - val_loss: 2.0775 - val_acc: 0.5215
# Epoch 29/75
# 22/22 [==============================] - 15s 677ms/step - loss: 0.5339 - acc: 0.8452 - val_loss: 1.6102 - val_acc: 0.6403
# Epoch 30/75
# 22/22 [==============================] - 17s 791ms/step - loss: 0.5064 - acc: 0.8559 - val_loss: 1.2049 - val_acc: 0.6898
# Epoch 31/75
# 22/22 [==============================] - 17s 762ms/step - loss: 0.4564 - acc: 0.8614 - val_loss: 1.1836 - val_acc: 0.7162
# Epoch 32/75
# 22/22 [==============================] - 14s 637ms/step - loss: 0.4265 - acc: 0.8717 - val_loss: 1.1163 - val_acc: 0.7459
# Epoch 33/75
# 22/22 [==============================] - 13s 610ms/step - loss: 0.4225 - acc: 0.8724 - val_loss: 0.9768 - val_acc: 0.7591
# Epoch 34/75
# 22/22 [==============================] - 14s 640ms/step - loss: 0.3835 - acc: 0.8879 - val_loss: 0.9511 - val_acc: 0.7624
# Epoch 35/75
# 22/22 [==============================] - 14s 629ms/step - loss: 0.4126 - acc: 0.8809 - val_loss: 1.2948 - val_acc: 0.7030
# Epoch 36/75
# 22/22 [==============================] - 14s 664ms/step - loss: 0.3497 - acc: 0.8926 - val_loss: 1.3158 - val_acc: 0.6898
# Epoch 37/75
# 22/22 [==============================] - 14s 617ms/step - loss: 0.3522 - acc: 0.8934 - val_loss: 1.4485 - val_acc: 0.6865
# Epoch 38/75
# 22/22 [==============================] - 13s 610ms/step - loss: 0.3338 - acc: 0.9007 - val_loss: 1.0401 - val_acc: 0.7426
# Epoch 39/75
# 22/22 [==============================] - 14s 617ms/step - loss: 0.2987 - acc: 0.9154 - val_loss: 1.1811 - val_acc: 0.7063
# Epoch 40/75
# 22/22 [==============================] - 14s 613ms/step - loss: 0.3160 - acc: 0.9059 - val_loss: 1.0647 - val_acc: 0.7558
# Epoch 41/75
# 22/22 [==============================] - 15s 661ms/step - loss: 0.3326 - acc: 0.9062 - val_loss: 1.0389 - val_acc: 0.7393
# Epoch 42/75
# 22/22 [==============================] - 14s 628ms/step - loss: 0.2606 - acc: 0.9217 - val_loss: 1.0224 - val_acc: 0.7789
# Epoch 43/75
# 22/22 [==============================] - 13s 609ms/step - loss: 0.2841 - acc: 0.9140 - val_loss: 1.1845 - val_acc: 0.7459
# Epoch 44/75
# 22/22 [==============================] - 14s 623ms/step - loss: 0.2637 - acc: 0.9165 - val_loss: 1.7101 - val_acc: 0.5941
# Epoch 45/75
# 22/22 [==============================] - 14s 616ms/step - loss: 0.2537 - acc: 0.9199 - val_loss: 1.4836 - val_acc: 0.6667
# Epoch 46/75
# 22/22 [==============================] - 13s 608ms/step - loss: 0.2640 - acc: 0.9243 - val_loss: 0.9176 - val_acc: 0.7987
# Epoch 47/75
# 22/22 [==============================] - 14s 615ms/step - loss: 0.2351 - acc: 0.9309 - val_loss: 1.1602 - val_acc: 0.7558
# Epoch 48/75
# 22/22 [==============================] - 14s 614ms/step - loss: 0.2487 - acc: 0.9221 - val_loss: 1.7150 - val_acc: 0.6271
# Epoch 49/75
# 22/22 [==============================] - 13s 596ms/step - loss: 0.2489 - acc: 0.9298 - val_loss: 0.9490 - val_acc: 0.7723
# Epoch 50/75
# 22/22 [==============================] - 13s 595ms/step - loss: 0.2273 - acc: 0.9272 - val_loss: 2.9981 - val_acc: 0.4356
# Epoch 51/75
# 22/22 [==============================] - 13s 606ms/step - loss: 0.2053 - acc: 0.9338 - val_loss: 3.2757 - val_acc: 0.3894
# Epoch 52/75
# 22/22 [==============================] - 13s 596ms/step - loss: 0.2326 - acc: 0.9331 - val_loss: 1.1842 - val_acc: 0.7327
# Epoch 53/75
# 22/22 [==============================] - 13s 605ms/step - loss: 0.2207 - acc: 0.9331 - val_loss: 1.6522 - val_acc: 0.6667
# Epoch 54/75
# 22/22 [==============================] - 13s 593ms/step - loss: 0.2198 - acc: 0.9430 - val_loss: 1.6135 - val_acc: 0.6568
# Epoch 55/75
# 22/22 [==============================] - 13s 612ms/step - loss: 0.1964 - acc: 0.9449 - val_loss: 1.3932 - val_acc: 0.7063
# Epoch 56/75
# 22/22 [==============================] - 14s 622ms/step - loss: 0.1683 - acc: 0.9463 - val_loss: 1.4282 - val_acc: 0.7327
# Epoch 57/75
# 22/22 [==============================] - 13s 606ms/step - loss: 0.1866 - acc: 0.9452 - val_loss: 1.2735 - val_acc: 0.7360
# Epoch 58/75
# 22/22 [==============================] - 14s 624ms/step - loss: 0.1870 - acc: 0.9449 - val_loss: 1.0527 - val_acc: 0.7756
# Epoch 59/75
# 22/22 [==============================] - 13s 603ms/step - loss: 0.1817 - acc: 0.9485 - val_loss: 1.1688 - val_acc: 0.7492
# Epoch 60/75
# 22/22 [==============================] - 13s 614ms/step - loss: 0.1620 - acc: 0.9500 - val_loss: 1.1387 - val_acc: 0.7261
# Epoch 61/75
# 22/22 [==============================] - 15s 697ms/step - loss: 0.1524 - acc: 0.9551 - val_loss: 2.0814 - val_acc: 0.5644
# Epoch 62/75
# 22/22 [==============================] - 15s 684ms/step - loss: 0.1834 - acc: 0.9445 - val_loss: 1.0201 - val_acc: 0.8119
# Epoch 63/75
# 22/22 [==============================] - 14s 621ms/step - loss: 0.1663 - acc: 0.9504 - val_loss: 1.6624 - val_acc: 0.6667
# Epoch 64/75
# 22/22 [==============================] - 14s 639ms/step - loss: 0.1670 - acc: 0.9496 - val_loss: 1.0320 - val_acc: 0.7822
# Epoch 65/75
# 22/22 [==============================] - 14s 630ms/step - loss: 0.1509 - acc: 0.9559 - val_loss: 0.9704 - val_acc: 0.8185
# Epoch 66/75
# 22/22 [==============================] - 13s 599ms/step - loss: 0.1560 - acc: 0.9526 - val_loss: 0.9935 - val_acc: 0.8053
# Epoch 67/75
# 22/22 [==============================] - 13s 596ms/step - loss: 0.1330 - acc: 0.9592 - val_loss: 1.1129 - val_acc: 0.7789
# Epoch 68/75
# 22/22 [==============================] - 13s 598ms/step - loss: 0.1375 - acc: 0.9551 - val_loss: 1.0261 - val_acc: 0.7888
# Epoch 69/75
# 22/22 [==============================] - 13s 601ms/step - loss: 0.1401 - acc: 0.9607 - val_loss: 1.4655 - val_acc: 0.7228
# Epoch 70/75
# 22/22 [==============================] - 13s 599ms/step - loss: 0.1700 - acc: 0.9496 - val_loss: 1.3309 - val_acc: 0.7129
# Epoch 71/75
# 22/22 [==============================] - 13s 597ms/step - loss: 0.1658 - acc: 0.9489 - val_loss: 2.0966 - val_acc: 0.6700
# Epoch 72/75
# 22/22 [==============================] - 13s 614ms/step - loss: 0.1374 - acc: 0.9559 - val_loss: 1.2534 - val_acc: 0.7327
# Epoch 73/75
# 22/22 [==============================] - 14s 634ms/step - loss: 0.1568 - acc: 0.9548 - val_loss: 2.3884 - val_acc: 0.5314
# Epoch 74/75
# 22/22 [==============================] - 14s 619ms/step - loss: 0.1591 - acc: 0.9526 - val_loss: 1.7186 - val_acc: 0.6568
# Epoch 75/75
# 22/22 [==============================] - 13s 613ms/step - loss: 0.1431 - acc: 0.9570 - val_loss: 0.9622 - val_acc: 0.7855
# 10/10 [==============================] - 0s 41ms/step - loss: 0.9622 - acc: 0.7855

# %%
# define the model4  architecture
model4 = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(train_x.shape[1],train_x.shape[2],1)),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.25),
    Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
    Dropout(0.5),
    Dense(len(subjects), activation='softmax')
])

# define learning rate scheduler
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1)

# define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

# compile the model
model4.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['acc'])

# fit the model with data augmentation and callbacks
history = model4.fit(train_x, train_y, epochs=150, batch_size=64, validation_data=(test_x, test_y))
# Out:
# Epoch 1/150
# 43/43 [==============================] - 6s 132ms/step - loss: 7.7800 - acc: 0.1522 - val_loss: 7.3925 - val_acc: 0.1485
# Epoch 2/150
# 43/43 [==============================] - 5s 124ms/step - loss: 6.4185 - acc: 0.2360 - val_loss: 6.4699 - val_acc: 0.1716
# Epoch 3/150
# 43/43 [==============================] - 6s 135ms/step - loss: 5.3836 - acc: 0.2923 - val_loss: 5.8079 - val_acc: 0.1221
# Epoch 4/150
# 43/43 [==============================] - 7s 163ms/step - loss: 4.5303 - acc: 0.3566 - val_loss: 5.3559 - val_acc: 0.2475
# Epoch 5/150
# 43/43 [==============================] - 7s 162ms/step - loss: 3.8339 - acc: 0.4349 - val_loss: 5.0577 - val_acc: 0.1650
# Epoch 6/150
# 43/43 [==============================] - 8s 179ms/step - loss: 3.2556 - acc: 0.4912 - val_loss: 4.9020 - val_acc: 0.1518
# Epoch 7/150
# 43/43 [==============================] - 8s 195ms/step - loss: 2.7548 - acc: 0.5717 - val_loss: 4.5215 - val_acc: 0.2871
# Epoch 8/150
# 43/43 [==============================] - 7s 161ms/step - loss: 2.4031 - acc: 0.6210 - val_loss: 4.5449 - val_acc: 0.1617
# Epoch 9/150
# 43/43 [==============================] - 7s 157ms/step - loss: 2.0451 - acc: 0.6919 - val_loss: 3.9168 - val_acc: 0.3267
# Epoch 10/150
# 43/43 [==============================] - 7s 175ms/step - loss: 1.7632 - acc: 0.7419 - val_loss: 3.6131 - val_acc: 0.3102
# Epoch 11/150
# 43/43 [==============================] - 7s 165ms/step - loss: 1.5748 - acc: 0.7654 - val_loss: 3.1714 - val_acc: 0.3828
# Epoch 12/150
# 43/43 [==============================] - 6s 151ms/step - loss: 1.3762 - acc: 0.8162 - val_loss: 2.7385 - val_acc: 0.4917
# Epoch 13/150
# 43/43 [==============================] - 6s 151ms/step - loss: 1.2187 - acc: 0.8441 - val_loss: 2.1765 - val_acc: 0.6271
# Epoch 14/150
# 43/43 [==============================] - 7s 158ms/step - loss: 1.1186 - acc: 0.8691 - val_loss: 1.8071 - val_acc: 0.7030
# Epoch 15/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.9895 - acc: 0.8952 - val_loss: 1.6821 - val_acc: 0.7228
# Epoch 16/150
# 43/43 [==============================] - 7s 155ms/step - loss: 0.9035 - acc: 0.9125 - val_loss: 1.5244 - val_acc: 0.7030
# Epoch 17/150
# 43/43 [==============================] - 7s 155ms/step - loss: 0.8400 - acc: 0.9232 - val_loss: 1.4993 - val_acc: 0.7459
# Epoch 18/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.7398 - acc: 0.9434 - val_loss: 1.4665 - val_acc: 0.7294
# Epoch 19/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.7104 - acc: 0.9463 - val_loss: 1.3513 - val_acc: 0.7327
# Epoch 20/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.6800 - acc: 0.9507 - val_loss: 1.6710 - val_acc: 0.6601
# Epoch 21/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.6360 - acc: 0.9478 - val_loss: 1.3245 - val_acc: 0.7393
# Epoch 22/150
# 43/43 [==============================] - 7s 169ms/step - loss: 0.5993 - acc: 0.9585 - val_loss: 1.1415 - val_acc: 0.8020
# Epoch 23/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.5489 - acc: 0.9688 - val_loss: 1.1727 - val_acc: 0.7558
# Epoch 24/150
# 43/43 [==============================] - 7s 172ms/step - loss: 0.5113 - acc: 0.9739 - val_loss: 1.3405 - val_acc: 0.7294
# Epoch 25/150
# 43/43 [==============================] - 8s 180ms/step - loss: 0.4946 - acc: 0.9721 - val_loss: 1.2653 - val_acc: 0.7360
# Epoch 26/150
# 43/43 [==============================] - 7s 172ms/step - loss: 0.4711 - acc: 0.9768 - val_loss: 1.1025 - val_acc: 0.7921
# Epoch 27/150
# 43/43 [==============================] - 7s 165ms/step - loss: 0.4599 - acc: 0.9739 - val_loss: 1.2228 - val_acc: 0.7591
# Epoch 28/150
# 43/43 [==============================] - 8s 177ms/step - loss: 0.4392 - acc: 0.9798 - val_loss: 1.2247 - val_acc: 0.7393
# Epoch 29/150
# 43/43 [==============================] - 7s 163ms/step - loss: 0.4209 - acc: 0.9783 - val_loss: 1.3041 - val_acc: 0.7393
# Epoch 30/150
# 43/43 [==============================] - 8s 178ms/step - loss: 0.3949 - acc: 0.9864 - val_loss: 0.9990 - val_acc: 0.8053
# Epoch 31/150
# 43/43 [==============================] - 7s 171ms/step - loss: 0.3756 - acc: 0.9864 - val_loss: 0.9954 - val_acc: 0.7987
# Epoch 32/150
# 43/43 [==============================] - 7s 166ms/step - loss: 0.3753 - acc: 0.9846 - val_loss: 1.0847 - val_acc: 0.7591
# Epoch 33/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.3682 - acc: 0.9838 - val_loss: 0.9949 - val_acc: 0.8020
# Epoch 34/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.3612 - acc: 0.9827 - val_loss: 1.0588 - val_acc: 0.7789
# Epoch 35/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.3571 - acc: 0.9838 - val_loss: 1.3300 - val_acc: 0.7096
# Epoch 36/150
# 43/43 [==============================] - 8s 175ms/step - loss: 0.3427 - acc: 0.9853 - val_loss: 0.9826 - val_acc: 0.7789
# Epoch 37/150
# 43/43 [==============================] - 7s 164ms/step - loss: 0.3327 - acc: 0.9868 - val_loss: 1.0611 - val_acc: 0.7954
# Epoch 38/150
# 43/43 [==============================] - 7s 163ms/step - loss: 0.3242 - acc: 0.9868 - val_loss: 0.9190 - val_acc: 0.8152
# Epoch 39/150
# 43/43 [==============================] - 7s 171ms/step - loss: 0.3197 - acc: 0.9871 - val_loss: 1.2479 - val_acc: 0.7063
# Epoch 40/150
# 43/43 [==============================] - 7s 167ms/step - loss: 0.3357 - acc: 0.9809 - val_loss: 1.0817 - val_acc: 0.7492
# Epoch 41/150
# 43/43 [==============================] - 7s 165ms/step - loss: 0.3262 - acc: 0.9857 - val_loss: 1.1155 - val_acc: 0.7723
# Epoch 42/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.3173 - acc: 0.9875 - val_loss: 1.1264 - val_acc: 0.7624
# Epoch 43/150
# 43/43 [==============================] - 7s 173ms/step - loss: 0.3305 - acc: 0.9801 - val_loss: 1.1224 - val_acc: 0.7525
# Epoch 44/150
# 43/43 [==============================] - 7s 172ms/step - loss: 0.3210 - acc: 0.9842 - val_loss: 1.3367 - val_acc: 0.7195
# Epoch 45/150
# 43/43 [==============================] - 7s 154ms/step - loss: 0.3105 - acc: 0.9871 - val_loss: 1.1791 - val_acc: 0.7492
# Epoch 46/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.3133 - acc: 0.9864 - val_loss: 1.3193 - val_acc: 0.7162
# Epoch 47/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.3092 - acc: 0.9853 - val_loss: 1.4093 - val_acc: 0.6898
# Epoch 48/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.3096 - acc: 0.9824 - val_loss: 1.5123 - val_acc: 0.6634
# Epoch 49/150
# 43/43 [==============================] - 7s 165ms/step - loss: 0.3293 - acc: 0.9801 - val_loss: 1.1909 - val_acc: 0.7657
# Epoch 50/150
# 43/43 [==============================] - 7s 174ms/step - loss: 0.3062 - acc: 0.9849 - val_loss: 1.0455 - val_acc: 0.8053
# Epoch 51/150
# 43/43 [==============================] - 7s 162ms/step - loss: 0.2844 - acc: 0.9890 - val_loss: 1.2763 - val_acc: 0.7426
# Epoch 52/150
# 43/43 [==============================] - 7s 166ms/step - loss: 0.2675 - acc: 0.9893 - val_loss: 1.1469 - val_acc: 0.7459
# Epoch 53/150
# 43/43 [==============================] - 7s 163ms/step - loss: 0.2637 - acc: 0.9912 - val_loss: 1.0475 - val_acc: 0.7723
# Epoch 54/150
# 43/43 [==============================] - 7s 166ms/step - loss: 0.2471 - acc: 0.9934 - val_loss: 0.9615 - val_acc: 0.7855
# Epoch 55/150
# 43/43 [==============================] - 7s 164ms/step - loss: 0.2478 - acc: 0.9915 - val_loss: 1.0614 - val_acc: 0.7789
# Epoch 56/150
# 43/43 [==============================] - 7s 171ms/step - loss: 0.2522 - acc: 0.9912 - val_loss: 1.1308 - val_acc: 0.7261
# Epoch 57/150
# 43/43 [==============================] - 7s 168ms/step - loss: 0.2551 - acc: 0.9912 - val_loss: 1.1083 - val_acc: 0.7690
# Epoch 58/150
# 43/43 [==============================] - 7s 162ms/step - loss: 0.2440 - acc: 0.9923 - val_loss: 1.3173 - val_acc: 0.7096
# Epoch 59/150
# 43/43 [==============================] - 7s 164ms/step - loss: 0.2438 - acc: 0.9912 - val_loss: 1.5131 - val_acc: 0.6601
# Epoch 60/150
# 43/43 [==============================] - 7s 160ms/step - loss: 0.2461 - acc: 0.9890 - val_loss: 1.2344 - val_acc: 0.7426
# Epoch 61/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.2419 - acc: 0.9904 - val_loss: 1.0452 - val_acc: 0.7855
# Epoch 62/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.2396 - acc: 0.9904 - val_loss: 1.0143 - val_acc: 0.7723
# Epoch 63/150
# 43/43 [==============================] - 7s 163ms/step - loss: 0.2318 - acc: 0.9919 - val_loss: 1.1769 - val_acc: 0.7360
# Epoch 64/150
# 43/43 [==============================] - 7s 170ms/step - loss: 0.2517 - acc: 0.9871 - val_loss: 1.1842 - val_acc: 0.7426
# Epoch 65/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.2415 - acc: 0.9908 - val_loss: 1.5976 - val_acc: 0.6634
# Epoch 66/150
# 43/43 [==============================] - 7s 172ms/step - loss: 0.2328 - acc: 0.9926 - val_loss: 1.1438 - val_acc: 0.7492
# Epoch 67/150
# 43/43 [==============================] - 7s 154ms/step - loss: 0.2330 - acc: 0.9893 - val_loss: 1.4039 - val_acc: 0.7063
# Epoch 68/150
# 43/43 [==============================] - 8s 177ms/step - loss: 0.2339 - acc: 0.9915 - val_loss: 0.9499 - val_acc: 0.7888
# Epoch 69/150
# 43/43 [==============================] - 7s 166ms/step - loss: 0.2185 - acc: 0.9941 - val_loss: 1.0333 - val_acc: 0.7558
# Epoch 70/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.2226 - acc: 0.9893 - val_loss: 1.4112 - val_acc: 0.6832
# Epoch 71/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.2388 - acc: 0.9871 - val_loss: 1.4675 - val_acc: 0.7162
# Epoch 72/150
# 43/43 [==============================] - 7s 154ms/step - loss: 0.2607 - acc: 0.9835 - val_loss: 1.3465 - val_acc: 0.7162
# Epoch 73/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.2824 - acc: 0.9812 - val_loss: 1.4085 - val_acc: 0.7426
# Epoch 74/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.3095 - acc: 0.9779 - val_loss: 1.2829 - val_acc: 0.7360
# Epoch 75/150
# 43/43 [==============================] - 7s 155ms/step - loss: 0.3188 - acc: 0.9805 - val_loss: 1.4069 - val_acc: 0.7162
# Epoch 76/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.3885 - acc: 0.9632 - val_loss: 3.3864 - val_acc: 0.3234
# Epoch 77/150
# 43/43 [==============================] - 7s 155ms/step - loss: 0.4324 - acc: 0.9588 - val_loss: 1.9305 - val_acc: 0.6568
# Epoch 78/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.4682 - acc: 0.9577 - val_loss: 2.0633 - val_acc: 0.6073
# Epoch 79/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.4681 - acc: 0.9581 - val_loss: 2.0170 - val_acc: 0.5974
# Epoch 80/150
# 43/43 [==============================] - 7s 155ms/step - loss: 0.4209 - acc: 0.9743 - val_loss: 1.4696 - val_acc: 0.7360
# Epoch 81/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.3605 - acc: 0.9835 - val_loss: 1.2054 - val_acc: 0.7690
# Epoch 82/150
# 43/43 [==============================] - 7s 155ms/step - loss: 0.3152 - acc: 0.9890 - val_loss: 1.3685 - val_acc: 0.7294
# Epoch 83/150
# 43/43 [==============================] - 7s 164ms/step - loss: 0.2684 - acc: 0.9937 - val_loss: 0.9115 - val_acc: 0.8053
# Epoch 84/150
# 43/43 [==============================] - 7s 167ms/step - loss: 0.2463 - acc: 0.9893 - val_loss: 1.0272 - val_acc: 0.7723
# Epoch 85/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.2248 - acc: 0.9923 - val_loss: 1.0865 - val_acc: 0.7657
# Epoch 86/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.2047 - acc: 0.9960 - val_loss: 1.1495 - val_acc: 0.7228
# Epoch 87/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1993 - acc: 0.9956 - val_loss: 0.9572 - val_acc: 0.7888
# Epoch 88/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1977 - acc: 0.9904 - val_loss: 1.0863 - val_acc: 0.7591
# Epoch 89/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1927 - acc: 0.9919 - val_loss: 0.8797 - val_acc: 0.8218
# Epoch 90/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1779 - acc: 0.9978 - val_loss: 0.8629 - val_acc: 0.7954
# Epoch 91/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1672 - acc: 0.9974 - val_loss: 0.7784 - val_acc: 0.8449
# Epoch 92/150
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1671 - acc: 0.9960 - val_loss: 0.8109 - val_acc: 0.8185
# Epoch 93/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1573 - acc: 0.9971 - val_loss: 0.7742 - val_acc: 0.8020
# Epoch 94/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.1558 - acc: 0.9974 - val_loss: 0.8289 - val_acc: 0.8218
# Epoch 95/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1564 - acc: 0.9967 - val_loss: 1.0132 - val_acc: 0.7723
# Epoch 96/150
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1511 - acc: 0.9971 - val_loss: 0.8016 - val_acc: 0.7987
# Epoch 97/150
# 43/43 [==============================] - 7s 167ms/step - loss: 0.1561 - acc: 0.9963 - val_loss: 0.7672 - val_acc: 0.8119
# Epoch 98/150
# 43/43 [==============================] - 7s 167ms/step - loss: 0.1564 - acc: 0.9960 - val_loss: 0.9225 - val_acc: 0.8053
# Epoch 99/150
# 43/43 [==============================] - 7s 167ms/step - loss: 0.1589 - acc: 0.9960 - val_loss: 1.0102 - val_acc: 0.7690
# Epoch 100/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.1605 - acc: 0.9956 - val_loss: 0.8747 - val_acc: 0.7921
# Epoch 101/150
# 43/43 [==============================] - 7s 168ms/step - loss: 0.1506 - acc: 0.9960 - val_loss: 0.8345 - val_acc: 0.8119
# Epoch 102/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1445 - acc: 0.9985 - val_loss: 0.7919 - val_acc: 0.8053
# Epoch 103/150
# 43/43 [==============================] - 7s 155ms/step - loss: 0.1491 - acc: 0.9952 - val_loss: 0.9765 - val_acc: 0.7822
# Epoch 104/150
# 43/43 [==============================] - 7s 166ms/step - loss: 0.1538 - acc: 0.9963 - val_loss: 0.8744 - val_acc: 0.7756
# Epoch 105/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1452 - acc: 0.9974 - val_loss: 0.8623 - val_acc: 0.8119
# Epoch 106/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1468 - acc: 0.9956 - val_loss: 0.8214 - val_acc: 0.8053
# Epoch 107/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1468 - acc: 0.9963 - val_loss: 2.6199 - val_acc: 0.5050
# Epoch 108/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1575 - acc: 0.9949 - val_loss: 1.2350 - val_acc: 0.7063
# Epoch 109/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1993 - acc: 0.9890 - val_loss: 1.2188 - val_acc: 0.7360
# Epoch 110/150
# 43/43 [==============================] - 7s 168ms/step - loss: 0.2400 - acc: 0.9805 - val_loss: 1.7787 - val_acc: 0.6997
# Epoch 111/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.2656 - acc: 0.9846 - val_loss: 1.5343 - val_acc: 0.6634
# Epoch 112/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.3230 - acc: 0.9691 - val_loss: 2.0009 - val_acc: 0.5974
# Epoch 113/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.4414 - acc: 0.9507 - val_loss: 4.0037 - val_acc: 0.3465
# Epoch 114/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.5489 - acc: 0.9408 - val_loss: 3.7143 - val_acc: 0.4389
# Epoch 115/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.5501 - acc: 0.9482 - val_loss: 2.8775 - val_acc: 0.5809
# Epoch 116/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.5735 - acc: 0.9438 - val_loss: 2.8384 - val_acc: 0.5512
# Epoch 117/150
# 43/43 [==============================] - 7s 164ms/step - loss: 0.5273 - acc: 0.9555 - val_loss: 1.8508 - val_acc: 0.6931
# Epoch 118/150
# 43/43 [==============================] - 7s 163ms/step - loss: 0.4419 - acc: 0.9761 - val_loss: 2.5520 - val_acc: 0.5875
# Epoch 119/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.3968 - acc: 0.9743 - val_loss: 1.6110 - val_acc: 0.7030
# Epoch 120/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.3533 - acc: 0.9772 - val_loss: 1.3215 - val_acc: 0.7723
# Epoch 121/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.3111 - acc: 0.9886 - val_loss: 3.5924 - val_acc: 0.4884
# Epoch 122/150
# 43/43 [==============================] - 7s 162ms/step - loss: 0.2714 - acc: 0.9890 - val_loss: 1.4027 - val_acc: 0.7459
# Epoch 123/150
# 43/43 [==============================] - 7s 154ms/step - loss: 0.2521 - acc: 0.9893 - val_loss: 1.1045 - val_acc: 0.7525
# Epoch 124/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.2165 - acc: 0.9967 - val_loss: 0.9056 - val_acc: 0.8020
# Epoch 125/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1913 - acc: 0.9952 - val_loss: 0.9863 - val_acc: 0.7987
# Epoch 126/150
# 43/43 [==============================] - 7s 156ms/step - loss: 0.1672 - acc: 0.9982 - val_loss: 0.8677 - val_acc: 0.8317
# Epoch 127/150
# 43/43 [==============================] - 7s 164ms/step - loss: 0.1534 - acc: 0.9974 - val_loss: 0.7882 - val_acc: 0.8218
# Epoch 128/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1448 - acc: 0.9993 - val_loss: 0.8028 - val_acc: 0.8185
# Epoch 129/150
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1324 - acc: 1.0000 - val_loss: 0.7212 - val_acc: 0.8251
# Epoch 130/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1313 - acc: 0.9974 - val_loss: 0.7639 - val_acc: 0.8218
# Epoch 131/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1413 - acc: 0.9949 - val_loss: 0.7663 - val_acc: 0.8317
# Epoch 132/150
# 43/43 [==============================] - 7s 163ms/step - loss: 0.1350 - acc: 0.9960 - val_loss: 0.8495 - val_acc: 0.7921
# Epoch 133/150
# 43/43 [==============================] - 7s 157ms/step - loss: 0.1313 - acc: 0.9978 - val_loss: 0.8462 - val_acc: 0.8053
# Epoch 134/150
# 43/43 [==============================] - 7s 164ms/step - loss: 0.1354 - acc: 0.9963 - val_loss: 0.8924 - val_acc: 0.8119
# Epoch 135/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.1351 - acc: 0.9978 - val_loss: 0.7444 - val_acc: 0.8383
# Epoch 136/150
# 43/43 [==============================] - 7s 161ms/step - loss: 0.1381 - acc: 0.9956 - val_loss: 0.7880 - val_acc: 0.8284
# Epoch 137/150
# 43/43 [==============================] - 7s 162ms/step - loss: 0.1295 - acc: 0.9978 - val_loss: 0.8089 - val_acc: 0.8053
# Epoch 138/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1287 - acc: 0.9978 - val_loss: 0.8670 - val_acc: 0.8119
# Epoch 139/150
# 43/43 [==============================] - 7s 166ms/step - loss: 0.1324 - acc: 0.9967 - val_loss: 0.9279 - val_acc: 0.7789
# Epoch 140/150
# 43/43 [==============================] - 7s 162ms/step - loss: 0.1255 - acc: 0.9978 - val_loss: 0.8078 - val_acc: 0.8119
# Epoch 141/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1243 - acc: 0.9971 - val_loss: 0.8501 - val_acc: 0.7921
# Epoch 142/150
# 43/43 [==============================] - 7s 169ms/step - loss: 0.1280 - acc: 0.9956 - val_loss: 0.8900 - val_acc: 0.7789
# Epoch 143/150
# 43/43 [==============================] - 7s 165ms/step - loss: 0.1267 - acc: 0.9960 - val_loss: 0.8793 - val_acc: 0.7921
# Epoch 144/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1256 - acc: 0.9974 - val_loss: 0.9313 - val_acc: 0.7921
# Epoch 145/150
# 43/43 [==============================] - 7s 162ms/step - loss: 0.1255 - acc: 0.9971 - val_loss: 0.8149 - val_acc: 0.8152
# Epoch 146/150
# 43/43 [==============================] - 7s 170ms/step - loss: 0.1271 - acc: 0.9963 - val_loss: 0.8037 - val_acc: 0.8152
# Epoch 147/150
# 43/43 [==============================] - 7s 160ms/step - loss: 0.1274 - acc: 0.9963 - val_loss: 0.8992 - val_acc: 0.7888
# Epoch 148/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1336 - acc: 0.9937 - val_loss: 0.9806 - val_acc: 0.7690
# Epoch 149/150
# 43/43 [==============================] - 7s 159ms/step - loss: 0.1450 - acc: 0.9945 - val_loss: 0.8799 - val_acc: 0.8086
# Epoch 150/150
# 43/43 [==============================] - 7s 158ms/step - loss: 0.1535 - acc: 0.9937 - val_loss: 0.8827 - val_acc: 0.7921

# %%
#accuracies
test_loss1, test_acc1 = model1.evaluate(test_x, test_y)
print("Accuracy of model 1 is {:.3f}".format(test_acc1))
test_loss2, test_acc2 = model2.evaluate(test_x, test_y)
print("Accuracy of model 2 is {:.3f}".format(test_acc2))
test_loss3, test_acc3 = model3.evaluate(test_x, test_y)
print("Accuracy of model 3 is {:.3f}".format(test_acc3))
test_loss4, test_acc4 = model4.evaluate(test_x, test_y)
print("Accuracy of model 4 is {:.3f}".format(test_acc4))
# Out:
# 10/10 [==============================] - 0s 10ms/step - loss: 4.8307 - acc: 0.6337
# Accuracy of model 1 is 0.634
# 10/10 [==============================] - 0s 21ms/step - loss: 2.0924 - acc: 0.7063
# Accuracy of model 2 is 0.706
# 10/10 [==============================] - 0s 38ms/step - loss: 0.9622 - acc: 0.7855
# Accuracy of model 3 is 0.785
# 10/10 [==============================] - 0s 21ms/step - loss: 0.8827 - acc: 0.7921
# Accuracy of model 4 is 0.792

# %%
# get a correctly identified image using sample CNN
train_pred = np.argmax(sample_cnn.predict(train_x), axis=1)
test_pred = np.argmax(sample_cnn.predict(test_x), axis=1)
correct_preds = np.where(test_pred == test_y)[0]
idx = np.random.choice(correct_preds)

# get the corresponding training image
training_idx = np.where(train_y == test_y[idx])[0][0]
training_img = train_x[training_idx]

# display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(test_x[idx, :, :, 0], cmap='gray')
ax1.set_title("Correctly identified image")
ax2.imshow(training_img[:, :, 0], cmap='gray')
ax2.set_title("Training image for correct subject")
plt.show()
# Out:
# 85/85 [==============================] - 2s 22ms/step
# 10/10 [==============================] - 0s 20ms/step

# %%
# get a correctly identified image using model 1
train_pred = np.argmax(model1.predict(train_x), axis=1)
test_pred = np.argmax(model1.predict(test_x), axis=1)
correct_preds = np.where(test_pred == test_y)[0]
idx = np.random.choice(correct_preds)

# get the corresponding training image
training_idx = np.where(train_y == test_y[idx])[0][0]
training_img = train_x[training_idx]

# display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(test_x[idx, :, :, 0], cmap='gray')
ax1.set_title("Correctly identified image")
ax2.imshow(training_img[:, :, 0], cmap='gray')
ax2.set_title("Training image for correct subject")
plt.show()
# Out:
# 85/85 [==============================] - 2s 23ms/step
# 10/10 [==============================] - 0s 24ms/step

# %%
# get a correctly identified image using model 2
train_pred = np.argmax(model2.predict(train_x), axis=1)
test_pred = np.argmax(model2.predict(test_x), axis=1)
correct_preds = np.where(test_pred == test_y)[0]
idx = np.random.choice(correct_preds)

# get the corresponding training image
training_idx = np.where(train_y == test_y[idx])[0][0]
training_img = train_x[training_idx]

# display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(test_x[idx, :, :, 0], cmap='gray')
ax1.set_title("Correctly identified image")
ax2.imshow(training_img[:, :, 0], cmap='gray')
ax2.set_title("Training image for correct subject")
plt.show()
# Out:
# 85/85 [==============================] - 2s 22ms/step
# 10/10 [==============================] - 0s 22ms/step

# %%
# get a correctly identified image using model 3 
train_pred = np.argmax(model3.predict(train_x), axis=1)
test_pred = np.argmax(model3.predict(test_x), axis=1)
correct_preds = np.where(test_pred == test_y)[0]
idx = np.random.choice(correct_preds)

# get the corresponding training image
training_idx = np.where(train_y == test_y[idx])[0][0]
training_img = train_x[training_idx]

# display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(test_x[idx, :, :, 0], cmap='gray')
ax1.set_title("Correctly identified image")
ax2.imshow(training_img[:, :, 0], cmap='gray')
ax2.set_title("Training image for correct subject")
plt.show()
# Out:
# 85/85 [==============================] - 2s 21ms/step
# 10/10 [==============================] - 0s 20ms/step

# %%
# get a correctly identified image using model 4
train_pred = np.argmax(model4.predict(train_x), axis=1)
test_pred = np.argmax(model4.predict(test_x), axis=1)
correct_preds = np.where(test_pred == test_y)[0]
idx = np.random.choice(correct_preds)

# get the corresponding training image
training_idx = np.where(train_y == test_y[idx])[0][0]
training_img = train_x[training_idx]

# display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(test_x[idx, :, :, 0], cmap='gray')
ax1.set_title("Correctly identified image")
ax2.imshow(training_img[:, :, 0], cmap='gray')
ax2.set_title("Training image for correct subject")
plt.show()
# Out:
# 85/85 [==============================] - 2s 22ms/step
# 10/10 [==============================] - 0s 21ms/step

# %%
# get an incorrectly identified image
incorrect_preds = np.where(test_pred != test_y)[0]
idx = np.random.choice(incorrect_preds)

# get the correct subject
correct_subject = np.argmax(test_y[idx])

# get the corresponding training image
training_idx = np.where(train_y == correct_subject)[0][0]
training_img = train_x[training_idx]

# display the images
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
ax1.imshow(test_x[idx, :, :, 0], cmap='gray')
ax1.set_title("Incorrectly identified image")
ax2.imshow(training_img[:, :, 0], cmap='gray')
ax2.set_title("Training image for correct subject")
plt.show()
